# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from    sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.svm  import SVC
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score,r2_score
from sklearn.preprocessing import LabelEncoder

# %%
df=sns.load_dataset('iris')
X=df.drop('species',axis=1)
y=df['species']
Xtrain, Xtest, ytrain, ytest = train_test_split(X, y, test_size=0.3, random_state=10)
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(Xtrain, ytrain)
ypred = model.predict(Xtest)
print(pd.DataFrame({'Actual': ytest, 'Predicted': ypred}))
print(classification_report(ytest, ypred))
acuuracy = accuracy_score(ytest, ypred)
print(f'Accuracy of the model is: {acuuracy*100:.2f}%')
print(confusion_matrix(ytest, ypred))
# Out:
#          Actual   Predicted
# 87   versicolor  versicolor
# 111   virginica   virginica
# 10       setosa      setosa
# 91   versicolor  versicolor
# 49       setosa      setosa
# 60   versicolor  versicolor
# 72   versicolor  versicolor
# 67   versicolor  versicolor
# 39       setosa      setosa
# 55   versicolor  versicolor
# 66   versicolor  versicolor
# 142   virginica   virginica
# 53   versicolor  versicolor
# 1        setosa      setosa
# 19       setosa      setosa
# 112   virginica   virginica
# 85   versicolor  versicolor
# 38       setosa      setosa
# 21       setosa      setosa
# 35       setosa      setosa
# 102   virginica   virginica
# 132   virginica   virginica
# 126   virginica   virginica
# 24       setosa      setosa
# 61   versicolor  versicolor
# 2        setosa      setosa
# 95   versicolor  versicolor
# 90   versicolor  versicolor
# 76   versicolor  versicolor
# 117   virginica   virginica
# 58   versicolor  versicolor
# 97   versicolor  versicolor
# ...

# %%
df
le=LabelEncoder()
df['species_n']=le.fit_transform(df['species'])
print(df)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  \
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
#      species_n
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
# ..         ...
# 145          2
# ...

# %%
df0=df[df.species=='setosa']
df0
df1=df[df.species=='virginica']
df1
df2=df[df.species=='versicolor']
df2
# Out:
#     sepal_length  sepal_width  petal_length  petal_width     species  \
# 50           7.0          3.2           4.7          1.4  versicolor
# 51           6.4          3.2           4.5          1.5  versicolor
# 52           6.9          3.1           4.9          1.5  versicolor
# 53           5.5          2.3           4.0          1.3  versicolor
# 54           6.5          2.8           4.6          1.5  versicolor
# 55           5.7          2.8           4.5          1.3  versicolor
# 56           6.3          3.3           4.7          1.6  versicolor
# 57           4.9          2.4           3.3          1.0  versicolor
# 58           6.6          2.9           4.6          1.3  versicolor
# 59           5.2          2.7           3.9          1.4  versicolor
# 60           5.0          2.0           3.5          1.0  versicolor
# 61           5.9          3.0           4.2          1.5  versicolor
# 62           6.0          2.2           4.0          1.0  versicolor
# ...

# %%
sns.scatterplot(x='petal_length', y='petal_width', data=df0,color='red')
sns.scatterplot(x='petal_length', y='petal_width', data=df1,color='blue')
sns.scatterplot(x='petal_length', y='petal_width', data=df2,color='green',marker='+',s=10)
# Out:
# <Axes: xlabel='petal_length', ylabel='petal_width'>

# %%
X=df.drop(['species','species_n'],axis=1)
y=df['species_n']
print(X.shape,y.shape)
X_train,X_test,Y_train,Y_test=train_test_split(X,y,test_size=0.3,random_state=42)
model=SVC(C=150,kernel='rbf',max_iter= 10)
model.fit(X_train,Y_train)
# Out:
# (150, 4) (150,)
# c:\Users\vinod\anaconda3\envs\decision-tree-masterclass\Lib\site-packages\sklearn\svm\_base.py:313: ConvergenceWarning: Solver terminated early (max_iter=10).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# SVC(C=150, max_iter=10)

# %%
y_pred=model.predict(X_test)
y_pred


print(model.score(X_test,Y_test))
# Out:
# 0.8666666666666667
